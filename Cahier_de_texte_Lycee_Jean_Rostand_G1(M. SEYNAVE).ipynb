# %% [markdown]
# # Séance 40 : 16 mars 2021 de 13h à 15h
# ## Activité en classe :
# * mini-projet : jeu du pendu
# * **bloc5/système d'exploitation** : droits et permissions
#
# ## Pour la prochaine séance :
#
# * terminer le jeu du pendu
#
# # Séance 39 : 11 mars 2021 de 16h à 18h
# ## Activité en classe :
#
# * **bloc5/systeme d'exploitation**
#     * cours logiciel libre
# * mini-projet : jeu du pendu
#
# ## Pour la prochaine séance :
#
# * continuer le mini-projet sur le jeu du pendu
#
# # Séance 38 : 9 mars 2021 de 13h à 15h
# ## Activité en classe :
#
# * **bloc6**
#     * TD boucles while
#
# * miniprojet : jeu du pendu
#
# ## Pour la prochaine séance :
#
# * continuer le mini-projet sur le jeu du pendu
#
# # Séance 37 : 18 février 2021 de 16h à 18h
# ## Activité en classe :
#
# * correction du DS
#
# * **bloc6**
#     * fin du cours while + TD boucles while
#
# ## Pour la prochaine séance :
#
# **bloc6** : while/ TD while/ exercice 13
#
# # Séance 36 : 16 février 2021 de 13h à 15h
# ## Activité en classe :
#
# * **bloc6**
#     * cours + TD boucles while
#
# ## Pour la prochaine séance :
#
# * **bloc6**
#     * TD boucles while : exercice 8
#
# # Séance 35 : 11 février 2021 de 16h à 18h
# ## Activité en classe :
#
# * **bloc6/boucles**
#     * cours + TD boucles while
#
# * **Devoir Surveillé**
#
# ## Pour la prochaine séance :
#
# * **bloc6/boucles**
#     * TD boucles while : exercice 4
#
# # Séance 34 : 09 février 2021 de 14h à 15h
# ## Activité en classe :
#
# * **bloc5/réseaux**
#     * Activité débranchée : protocole TCP et modèle TCP/IP (encapsulation)
#
# ## Pour la prochaine séance :
#
# **DS prévu le 11 février** : boucles (for), opérateurs booléens (and, or etc...), représentation du texte en machine (ascii, latin1, UTF8)
#
#
# # Séance 33 : 04 février 2021 de 16h à 18h
# ## Activité en classe :
#
# * **bloc6/boucles**
#     * TD boucles : correction de l'exercice 9
#     * TD boucles : exercices 6, 7 et 10
#     * Fin du TP Art-Ascii
#
# ## Pour la prochaine séance :
#
# **DS prévu le 11 février** : boucles (for), opérateurs booléens (and, or etc...), représentation du texte en machine (ascii, latin1, UTF8)
#
# # Séance 32 : 02 février 2021 de 13h à 15h
# ## Activité en classe :
#
# * **bloc5/architecture_reseau**
#     * cours (3 et 5)
#     * TP filius
#
# ## Pour la prochaine séance :
#
# * **bloc6/boucles**
#     * TD boucles : exercice 9 (à déposer dans votre github)
#
# # Séance 31 : 28 janvier 2021 de 16h à 18h
# ## Activité en classe :
#
# * **bloc6/boucles**
#     * TD boucles : correction de l'exercice 8
#     * TD boucles : exercice 3 (Q4 et Q5) + exercice 6
#     * Fin du TP turtle
#     * TP Art-Ascii
#
# ## Pour la prochaine séance :
#
# * **bloc6/boucles**
#     * TD boucles : exercice 9 (à déposer dans votre github).
#
# # Séance 30 : 26 janvier 2021 de 13h à 16h
# ## Activité en classe :
#
# * **bloc6/boucles**
#     * corrections de l'exercice 5
#
# * **bloc5/architecture_reseau**
#     * cours (sauf 3 et 5)
#     * TD masques (exercice 1)
#
# ## Pour la prochaine séance :
#
# * **bloc6/boucles**
#     * TD boucles : exercice 8 (à déposer dans votre github)
#
# # Séance 29 : 21 janvier 2021 de 16h à 18h
# ## Activité en classe :
#
# * **bloc1/operateurs booléens**
#     * correction de l'exercice 9
#
# * **bloc6/boucles**
#     * corrections des exercices 3 et 4
#     * fin du cours boucle
#     * TP turtle
#
# ## Pour la prochaine séance :
#
# * **bloc6/boucles**
#     * TD boucles : exercice 5 (à déposer dans votre github)
#
# # Séance 28 : 14 janvier 2021 de 16h à 18h
# ## Activité en classe :
#
# * **bloc6/boucles**
#     * TD boucles for : correction des exercices 1 et 2
#     * cours boucle for
#     * TD boucles for : exercices 3 (jusqu'à Q3) et 4
#
# ## Pour la prochaine séance :
#
# * **bloc6/boucles**
#     * Terminer les exercices 3 et 4
#
# * **bloc1/operateurs booléens**
#     * exercice 9
#
#
# # Séance 27 : 12 janvier 2021 de 13h à 15h
# ## Activité en classe :
#
# * correction du DS
#
# * **bloc1/opérateurs booléens**
#     * TD opérateurs booléens : correction des exercices 6 et 13
#
# * **bloc6/boucles**
#     * cours boucle for (début jusqu'à "Parcourir la séquence VS parcourir les indices de la séquence")
#     * TD boucle for : exercices 1 et 2
#
# ## Pour la prochaine séance :
#
# * **bloc6/boucles**
#     * TD boucle for : exercices 1 et 2
#
# * **bloc1/opérateurs booléens**
#     * TD opérateurs booléens : exercice 12 (Question 2 uniquement)
#
# # Séance 26 : 7 janvier 2021 de 16h à 18h
# ## Activité en classe :
#
# * **bloc1/opérateurs booléens**
#     * TD opérateurs booléens : correction des exercices 3 et 10
#     * TD opérateurs booléens : débuter les exercices 4, 5 et 8
#     * TD opérateurs booléens : exercice 7
#
# ## Pour la prochaine séance :
#
# * **bloc1/opérateurs booléens**
#     * TD opérateurs booléens : terminer les exercices 4, 5, 7, 8
#     * TD opérateurs booléens : exercices 6 et 13
#
#
# # Séance 25 : 5 janvier 2021 de 13h à 18h
# ## Activité en classe :
#
# * **bloc1/representation du texte**
#     * TD representation du texte en machine : correction de l'exercice 10
#
# * **bloc1/opérateurs booléens**
#     * cours opérateurs booléens
#     * TD opérateurs booléens : exercices 1 et 2
#
# ## Pour la prochaine séance :
#
# * **bloc1/opérateurs booléens**
#     * TD opérateurs booléens : exercices 3 et 10
#
# # Séance 24 : 17 décembre 2020 de 14h à 16h
# ## Activité en classe :
#
# * **bloc1/representation du texte**
#     * TD representation du texte en machine : correction de l'exercice 6
#     * TD representation du texte en machine : exercices 7, 8, 9, 11
#
# ## Pour la prochaine séance :
#
# * **bloc1/representation du texte**
#     * TD representation du texte en machine : exercices 10 et 12
#
# # Séance 23 : 15 décembre 2020 de 13h à 15h
# ## Activité en classe :
#
# * **bloc1/representation du texte**
#     * TD le type chaine de caractere : exercice 4
#     * TD representation du texte en machine : correction des exercices 1 à 5
#     * fin du cours representation du texte en machine
#     * TD representation du texte en machine : exercice 6
#
# ## Pour la prochaine séance :
#
# * **bloc1/representation du texte**
#     * TD representation du texte en machine : exercice 6
#
# # Séance 22 : 10 décembre 2020 de 16h à 18h
# ## Activité en classe :
#
# * **DS 1h-2h** (Les élèves qui ont fini avant avancent sur le travail à faire à la maison)
#
#
# ## Pour la prochaine séance :
#
# * **bloc1/representation du texte**
#     * TD representation du texte en machine : terminer les exercices 1 à 5
#
# # Séance 21 : 8 décembre 2020 de 13h à 15h
# ## Activité en classe :
#
# * **bloc1/representation du texte**
#     * TD le type chaine de caracteres : correction des exercices 1 à 3
#     * Cours representation du texte en machine (début)
#     * TD representation du texte en machine (exercices 1 à 5)
#
# ## Pour la prochaine séance :
#
# * **Devoir Surveillé (tout depuis le début de l'année)**
# * **bloc1/representation du texte**
#     * TD le type chaine de caracteres : exercice 4 (pour ceux qui ont fini à l'avance)
#
# # Séance 20 : 3 décembre 2020 de 16h à 18h
# ## Activité en classe :
#
# * **bloc6/bibliothèques**
#     * synthèse rapide du TP programmation modulaire
#
# * **bloc6/instrcuctions conditionnelles**
#     * correction rapide des exercices 6 et 7
#
# * **bloc1/representation du texte**
#     * cours le type chaîne de caractères
#     * TD le type chaîne de caractères
#
# ## Pour la prochaine séance :
#
# * **bloc1/representation du texte**
#     * TD le type chaîne de caractères : exercice 3
#
# * **bloc4/CSS**
#     * rendre TP_CSS
#
# * **DS (1h) prévu le jeudi 10 décembre (tout depuis le début de l'année)**
#
# # Séance 19 :  01 décembre 2020 de 13h à 15h
#
# ## Activité en classe
#
# * **bloc6/bibliothèques**
#     * TP_programmation_modulaire
#
# * **bloc5/systeme d'exploitation**
#     * TD chemin : correction de l'exercice 7
#
# * **bloc4/CSS**
#     * Cours CSS
#     * TP_CSS
#
#
# ## Pour la prochaine séance :
#
# * **bloc6/bibliothèques**
#     * finir TP_programmation_modulaire (à déposer dans votre github au bon endroit !!!)
#
# * **bloc4/CSS**
#     * commencer TP_CSS
#
# * **DS (1h) prévu le jeudi 10 décembre (tout depuis le début de l'année)**
#
# # Séance 18:  26 novembre 2020 de 16h à 18h - M. Zouaoui
# ## Activité en classe :
#
# * **bloc6/bibliothèques**
#     * cours bibliothèques
#     * TP_programmation_modulaire
#
# ## Pour la prochaine séance :
#
# * **bloc6/bibliothèques**
#     * Terminer TP_programmation_modulaire
#
# # Séance 17 :  24 novembre 2020 de 13h à 15h
# ## Activité en classe :
#
# * **bloc5/systeme_exploitation :**
#     * (1) TD_chemins : Correction des exercices 1 et 2
#
#
# * **bloc6/instructions conditionnelles**
#     * (2) TD instructions conditionnelles : correction de l'exercice 3
#     * (3) fin du cours instructions conditionnelles
#     * (4) TD instructions conditionnelles 4 et 5
#
#
# ## Pour la prochaine séance :
#
# * **bloc5/systeme_exploitation :**
#    * TD chemins : exercice 7
#
#
# # Séance 16 :  19 novembre 2020 de 16h à 18h
# ## Activité en classe :
#
# * **Bloc4/HTML**
#     * Correction TP_HTML
#
# * **bloc5/systeme_exploitation :**
#     * (1) TD_chemins : correction des Exercices 2, 4 et 6
#
# * **bloc6/instructions conditionnelles**
#     * (2) début cours instructions conditionnelles
#     * (3) TD instructions conditionnelles : exercices 1 et 2
#
# ## Pour la prochaine séance :
#
# * **bloc5/systeme_exploitation :**
#     * TD_chemins : Exercices 1 et 3
#
# * **bloc6/instructions conditionnelles**
#     * TD instructions conditionnelles : exercice 3 (Ne pas oublier d'écrire la documentation des fonctions)
#
#
#
# # Séance 15 :  10 novembre 2020 de 16h à 18h
# ## Activité en classe :
#
# * **bloc5/systeme_exploitation :**
#     * TP_commandes_de_base_GNU_Linux
#
# ## Pour la prochaine séance :
#
# * **bloc5/systeme_exploitation :**
#     * (4) TD_chemins : Exercices 2, 4 et 6
#
# # Séance 14 : 5 novembre 2020 de 16h à 18h
# ## Activité en classe :
#
# * **bloc6/fonctions :**
#     * (1) correction TD_fonctions : exercice 5
#     * (2) TD_fonctions : exercice 6
#
# * **bloc5/systeme_exploitation :**
#     * (3) Cours_Linux_systeme_de_fichiers
#
# ## Pour la prochaine séance :
#
# * **bloc5/systeme_exploitation :**
#     * (4) TD_chemins : Exercices 2, 4 et 6
#
# # Séance 13 : 3 novembre 2020 de 13h à 15h
# ## Activité en classe :
#
# * **bloc6/fonctions :**
#     * (1) fin du cours definition de fonction (documentation et notion de variables locales)
#     * (2) correction TD_fonctions (Exercices 2 et 4)
#     * (3) TD_fonctions : exercice 3
#
# * (4) Correction QCM1
#
# * **bloc5/systeme_exploitation :**
#     * (5) Cours_systeme_exploitation_Linux
#
#
# ## Pour la prochaine séance :
#
# * **bloc6/fonctions :**
#     * TD_fonctions : exercice 5
#
# ## Pour la prochaine séance :
#
#
# # VACANCES DE TOUSSAINT
#
# # Séance 12 : 15 octobre 2020 de 16h à 18h
# ## Activité en classe :
#
# * **bloc4/HTML**
#     * (1) synthèse TD HTML Exercices 4 et 5
#
# * **bloc6/fonctions**
#     * (2) Cours définition de fonctions
#     * (3) TD_les fonctions : exercice 2
#
# ## Pour la prochaine séance :
#
# * **bloc6/fonctions :**
#     * TD_les fonctions : exercices 2 et 4. Pour cela écrire un fichier appelé `TD_fonctions` à déposer sur github dans un dossier `bloc6/fonction`
#
# * **bloc4/HTML :**
#     * TP_HTML. Ceci est un DM qui va vous demander plus de temps (organisez-vous !!). Le code HTML doit être écrit dans un fichier `TP_HTML` déposé sur github dans un dossier `bloc4/HTML`.
#
# # Séance 11 : 13 octobre 2020 de 13h à 15h
# ## Activité en classe :
#
# * **bloc6/fonctions**
#     * (1) début Cours définition de fonctions
#
# * (2) Evaluation QCM1
#
# ## Pour la prochaine séance :
#
# * **bloc6/fonctions**
#     * TD_fonctions (exercice1). Pour cela écrire un fichier appelé `TD_fonctions` à déposer sur github dans un dossier `bloc6/fonction`
#
# # Séance 10 : 08 octobre 2020 de 16h à 18h
# ## Activité en classe :
#
# * (1) Comment aborder l'épreuve de QCM ?
#
# * **bloc1/ecriture_entier_positif**
#     * (2) correction du TD image
#
# * **bloc4/HTML**
#     * (3) TD HTML exercice 4
#
# ## Pour la prochaine séance :
#
# * **bloc4/HTML**
#     * (3) TD HTML exercice 5 (à déposer dans github)
#
# * **Evaluation de type QCM prévue le mardi 13 octobre**. A revoir : bloc1 (tout) +  bloc6 (initiation à python + appels de fonction).
#
# # Séance 9 : 06 octobre 2020 de 13h à 15h
# ## Activité en classe :
#
# * **bloc1/ecriture_entier_positif**
#     * (1) correction du TD montre binaire
#     * (2) TD codage d'une date
#
# * **bloc4/HTML**
#     * (3) TD HTML exercices 2 + 3 + 4(debut)
#
# ## Pour la prochaine séance :
#
# * **bloc1/ecriture_entier_positif**
#     * TD_image sur feuille (il faudra notamment recopier la grille sur feuille et la compléter)
# * **Evaluation de type QCM prévue le mardi 13 octobre**. A revoir : bloc1 (tout) +  bloc6 (initiation à python + appels de fonction) et lire le fichier `/Informations_diverses/Epreuve_NSI_au_baccalaureat` pour avoir des informations sur la nature de l'épreuve.
#
# # Séance 8 : 01 octobre 2020 de 16h à 18h
# ## Activité en classe :
#
# * **bloc6/fonctions**
#     * (1) correction exercice 4 de bloc6/fonctions/TD appel de fonction
#
# * **bloc1/ecriture_entier_positif**
#     * (2) TD numération : exercice 7
#
# * **bloc4/HTML**
#     * (3) Cours HTML
#
# ## Pour la prochaine séance :
#
# * **bloc1/ecriture_entier_positif**
#     * TD_montre_binaire
# * Installer [ATOM](https://atom.io/) à la maison. Le télécharger. En cas de souci (improbable), vous pouvez installer [Notepad++](https://notepad-plus-plus.org/downloads/v7.8.8/). Bien faire attention à choisir la version de windows (64 ou 32 bits) correspondant à votre système d'exploitation
# * **bloc4/HTML**
#     * Commencer l'exercice 2 du TD HTML
#
# # Séance 7 : 29 septembre 2020 de 13h à 15h
# ## Activité en classe :
#
# * **bloc1/ecriture_entier_positif**
#     * (1) Correction des Exercices 3 et 5 du TD numération
#
# * **bloc6/fonctions**
#     * (2) Cours appels de fonction
#     * (3) TD appels de fonctions : exercices 1 à 3
#
# ## Pour la prochaine séance :
# * bloc6/fonctions/TD_appel_de_fonctions : Exercice 4
#
# # Séance 6 : 24 septembre 2020 de 16h à 18h - M. Zouaoui
# ## Activité en classe :
#
# * **bloc1/ecriture_entier_positif**
#     * (1) TD numération : exercices 1.3, 2, 4, 6
#
# * **bloc6/initiation_a_python**
#     * (2) TD_Les_bases_de_python.ipynb : exercices 7, 8, 10, 11, 12
#
# ## Pour la prochaine séance :
# * bloc1/ecriture_entier_positif : TD numeration exercices 3 et 5
#
# # Séance 5 : 22 septembre 2020 de 13h à 15h
# ## Activité en classe :
#
# * **bloc1/ecriture_entier_positif**
#     * (1) correction TD numeration : Exercices 1.1 et 1.2
#     * (2) fin cours_representation_entier_positif.ipynb
#
# * **bloc6/initiation_a_python**
#     * (3) TD_Les_bases_de_python.ipynb : exercice 9
#
# ## Pour la séance du 1er octobre:
# * bloc1/ecriture_entier_positif : TD numeration exercices 3 et 5
#
# # Séance 4 : 17 septembre 2020 de 16h à 18h
# ## Activité en classe :
#
# * **bloc6/initiation_a_python**
#     * (1) Correction exercice 4 et 5 du TD_Les_bases_de_python.ipynb
#     * (2) TD_Les_bases_de_python.ipynb Exercice 6
#
# * **bloc1**
#     * (3) fin Cours_Introduction_a_la_representation_des_donnees.ipynb
#
# * **bloc1/ecriture_entier_positif**
#     * (4) cours_representation_entier_positif.ipynb
#
# ## Pour la prochaine séance :
#
# * **bloc1/ecriture_entier_positif**
#     * TD numération exercice 1.1 et 1.2
#
# # Séance 3 : 10 septembre 2020 de 16h à 18h
# ## Activité en classe :
#
# * **bloc6/initiation_a_python**
#     * (1) fin du Cours_Variables_et_types_simples_en_python
#     * (2) TD_Les_bases_de_python.ipynb : Activité0 puis Exercices 3 et 4
#
# * **bloc1**
#     * (3) début Cours_Introduction_a_la_representation_des_donnees.ipynb
#
# ## Pour la prochaine séance :
#   * Faire sur feuille l'exercice 5 du TD_Les_bases_de_python.ipynb (pour cela, utiliser le Cours_Variables_et_types_simples_en_python)
#   * (Re)pratiquer / (Re)lire les activités de la séance 3
#
#
# # Séance 2 : 8 septembre 2020 de 13h à 15h
# ## Activité en classe :
#
# * **bloc6/initiation_a_python**
#     * (1) TD_Le_shell_de_python.ipynb
# 	* (2) Cours_Variables_et_types_simples_en_python
#     * (3) TD_Les_bases_de_python.ipynb exercices 1 et 2
#
# ## Pour la prochaine séance :
#   * Installer Thonny à la maison (Penser à ouvrir le fichier `premiere/Outils_et_environnement_informatiques/Thonny` si nécessaire)
#   * (Re)pratiquer / (Re)lire les activités de la séance 2
#
# > **Rappel** :
# * *En informatique, les parties du programme ne sont pas indépendantes les unes des autres. Nous voyons en ce moment **les fondations** dont on se servira tout le temps après !*
# * _Apprendre son cours c'est bien mais c'est insuffisant : En python, le plus important c'est **la pratique**_
#
# # Séance 1 : 3 septembre 2020 de 16h à 18h
# ## Activité en classe :
# * **Rentrée :**
#     * (1) Questionnaire de rentrée (connaissance en informatique)
# 	* (2) Création d'un _repository_ privé sur **github**
#
# * **bloc6/initiation_a_python**
# 	* (3) Cours Introduction au langage python
#     * (4) Cours Découverte de Python
#
# ## Pour la prochaine séance :
#   * Lire les 7 fichiers d'extension `.ipynb` disponibles dans informations_diverses (De désagréables surprises attendent ceux qui ne le font pas).
#   * (Re)pratiquer / (Re)lire les activités de la séance 1
#
# # A venir...
#
# # Séance 41 : 18 mars 2021 de 16h à 18h
# ## Activité en classe :
# * **bloc5/système d'exploitation** :
#     TP droits et permissions
#
# * synthèse du mini-projet "jeu du pendu"
#
# * **bloc2**
#     * Cours liste
#     * TD liste
#
# ## Pour la prochaine séance :
#
# # Reste du programme de cette année de première :
#
# * droits OS + OS libre vs propriétaire
# * listes, tuple P
# * javascript : événement
# * Algorithmique : parcours séquentiel dans un tableau P
#
# notice markdown + notebook
#
# * entier relatif x
# * dictionnaires P AF
# * Architecture des ordinateurs
# * specification d'une fonction P
# * protocole HTTP et interaction client / serveur
# * tests P AF*
# * formulaire javascript + flask
# * flottant x
# * matrice liste en compréhension (ajouter des exercices sur la recherche sequentielle ds un tableau à 2 dimensions) P AF
# * arduino AF
# * tables x
# * dichotomie P AF
# * algo knn x
# * tris P
# * gloutons x
#
# projet :
# * IHM TkinterP AF
